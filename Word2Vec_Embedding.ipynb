# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/MyDrive/NLP\ Project
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/NLP Project

# %%
import pickle
import torch

# %%
with open ('HateXPlainData/trainHateXplain', 'rb') as fp:
    train = pickle.load(fp)

print(train[0])
# Out:
# (['u', 'really', 'think', 'i', 'would', 'not', 'have', 'been', 'raped', 'by', 'feral', 'hindu', 'or', 'muslim', 'back', 'in', 'india', 'or', 'bangladesh', 'and', 'a', 'neo', 'nazi', 'would', 'rape', 'me', 'as', 'well', 'just', 'to', 'see', 'me', 'cry'], 'offensive')
